# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Seminar - APIs, DBs and Live coding

# %% [markdown]
# ## Task 1: Requesting API
# ### 1a. Create a function requesting data from sreality
#
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# * function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - use 10 as default value
#     * `page` parameter
# * use string inputs for `category_main_cb` and `category_type_cb`
# * include try/except clause to handle errors
# * function should return JSON data in python types
# * do not forget to sleep each request at least 0.5s

# %%
price = 10
print(f"our price is {price}")
# Out:
# our price is 10

# %%
template_url = 'https://egory_main_cb={category_main}'
template_url.format(category_main=5)
# Out:
# 'https://egory_main_cb=5'

# %%
def request_sreality(page, category_main_str, category_type_str, locality_region_id=10):
    time.sleep(0.5)
    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    try:
        template_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main}&category_type_cb={category_type}&locality_region_id={locality_region_id}&per_page60&page={page}'
        request_url = template_url.format(
            category_main=category_mains[category_main_str],
            category_type=category_types[category_type_str],
            locality_region_id=locality_region_id,
            page=page
        )
        r = requests.get(request_url)
        return r.json()
    except Exceptions as e:
        print(e)

# %%
d = request_sreality(0, 'flat', 'sell', 10)
d["_embedded"]["estates"][0].keys()
# Out:
# dict_keys(['labelsReleased', 'has_panorama', 'labels', 'is_auction', 'labelsAll', 'seo', 'exclusively_at_rk', 'category', 'has_floor_plan', '_embedded', 'paid_logo', 'locality', 'has_video', 'advert_images_count', 'new', 'auctionPrice', 'type', 'hash_id', 'attractive_offer', 'price', 'price_czk', '_links', 'rus', 'name', 'region_tip', 'gps', 'has_matterport_url'])

# %%
pd.DataFrame(d["_embedded"]["estates"])
# Out:
#                                 labelsReleased  has_panorama  \
# 0                    [[], [shop, post_office]]             0
# 1                        [[loggia, panel], []]             0
# 2                         [[parking_lots], []]             0
# 3                                [[], [train]]             0
# 4                            [[furnished], []]             0
# 5   [[after_reconstruction, terrace], [metro]]             0
# 6       [[new_building], [metro, post_office]]             0
# 7                   [[], [train, post_office]]             0
# 8                          [[], [metro, shop]]             0
# 9                                     [[], []]             0
# 10                  [[balcony, furnished], []]             0
# 11                        [[balcony], [medic]]             0
# 12               [[terrace, parking_lots], []]             0
# 13                        [[parking_lots], []]             0
# 14               [[balcony, parking_lots], []]             0
# 15                    [[panel, furnished], []]             0
# 16                       [[loggia, panel], []]             0
# 17         [[parking_lots, not_furnished], []]             0
# 18              [[collective, panel], [metro]]             0
# 19      [[loggia, panel], [shop, post_office]]             0
#
#                                                labels  is_auction  \
# 0           [Obchod 6 min. pěšky, Pošta 4 min. pěšky]       False
# 1                                  [Lodžie, Panelová]       False
# 2                                         [Parkování]       False
# 3                               [Vlak 86 metrů pěšky]       False
# 4                                          [Vybavený]       False
# 5       [Po rekonstrukci, Terasa, Metro 4 min. pěšky]       False
# 6   [Novostavba, Metro 3 min. pěšky, Pošta 2 min. ...       False
# 7             [Vlak 6 min. pěšky, Pošta 6 min. pěšky]       False
# 8     [Metro 323 metrů pěšky, Obchod 390 metrů pěšky]       False
# 9                                                  []       False
# 10                                 [Balkon, Vybavený]       False
# 11                       [Balkon, Lékař 7 min. pěšky]       False
# 12                                [Terasa, Parkování]       False
# 13                                        [Parkování]       False
# 14                                [Balkon, Parkování]       False
# 15                               [Panelová, Vybavený]       False
# 16                                 [Lodžie, Panelová]       False
# 17                            [Parkování, Nevybavený]       False
# 18         [Družstevní, Panelová, Metro 7 min. pěšky]       False
# 19  [Lodžie, Panelová, Obchod 6 min. pěšky, Pošta ...       False
#
#                                             labelsAll  \
# 0   [[personal, brick], [candy_shop, small_shop, t...
# 1   [[personal, loggia, panel, cellar, elevator], ...
# 2       [[personal, brick, cellar, parking_lots], []]
# 3   [[personal, brick, cellar], [school, small_sho...
# 4   [[personal, brick, elevator, furnished], [vet,...
# 5   [[personal, after_reconstruction, terrace, bri...
# 6   [[new_building, personal], [small_shop, tavern...
# 7   [[personal, brick, partly_furnished], [small_s...
# 8   [[personal, brick, cellar, elevator, partly_fu...
# 9   [[personal, brick, partly_furnished], [candy_s...
# 10  [[personal, balcony, brick, cellar, furnished]...
# 11  [[personal, balcony, brick, elevator, partly_f...
# 12  [[personal, terrace, brick, cellar, parking_lo...
# 13  [[personal, brick, cellar, parking_lots], [the...
# 14  [[personal, balcony, brick, cellar, elevator, ...
# 15  [[personal, panel, elevator, furnished], [smal...
# 16  [[personal, loggia, panel, cellar, partly_furn...
# 17  [[personal, brick, elevator, parking_lots, not...
# 18  [[collective, panel, elevator, partly_furnishe...
# 19  [[personal, loggia, panel, cellar, elevator, p...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 1   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 2   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 3   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 4   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 5   {'category_main_cb': 1, 'category_sub_cb': 10,...                  0
# 6   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 7   {'category_main_cb': 1, 'category_sub_cb': 3, ...                  1
# 8   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 9   {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# 10  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 11  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 12  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 13  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 14  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 15  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 16  {'category_main_cb': 1, 'category_sub_cb': 9, ...                  1
# 17  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 18  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 19  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
#
#     category  has_floor_plan  \
# 0          1               0
# 1          1               1
# 2          1               0
# 3          1               1
# 4          1               0
# 5          1               0
# 6          1               1
# 7          1               0
# 8          1               0
# 9          1               1
# 10         1               1
# 11         1               1
# 12         1               0
# 13         1               0
# 14         1               0
# 15         1               0
# 16         1               0
# 17         1               0
# 18         1               1
# 19         1               0
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  3643360332
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  4037748300
# 2   {'favourite': {'is_favourite': False, '_links'...  ...   642017628
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  2215548236
# 4   {'favourite': {'is_favourite': False, '_links'...  ...  3432031308
# 5   {'favourite': {'is_favourite': False, '_links'...  ...  3609708108
# 6   {'favourite': {'is_favourite': False, '_links'...  ...  3075359820
# 7   {'favourite': {'is_favourite': False, '_links'...  ...  1376974156
# 8   {'favourite': {'is_favourite': False, '_links'...  ...  1947661644
# 9   {'favourite': {'is_favourite': False, '_links'...  ...  1725560140
# 10  {'favourite': {'is_favourite': False, '_links'...  ...  1854309708
# 11  {'favourite': {'is_favourite': False, '_links'...  ...  1097049420
# 12  {'favourite': {'is_favourite': False, '_links'...  ...  1028359244
# 13  {'favourite': {'is_favourite': False, '_links'...  ...   505779276
# 14  {'favourite': {'is_favourite': False, '_links'...  ...  1934292300
# 15  {'favourite': {'is_favourite': False, '_links'...  ...  2288297292
# 16  {'favourite': {'is_favourite': False, '_links'...  ...  2701755724
# 17  {'favourite': {'is_favourite': False, '_links'...  ...   716600396
# 18  {'favourite': {'is_favourite': False, '_links'...  ...  1314628940
# 19  {'favourite': {'is_favourite': False, '_links'...  ...  2653242444
#
#    attractive_offer     price  \
# 0                 0  13923000
# 1                 0   8143000
# 2                 0   7711000
# 3                 0   7976000
# 4                 0  10061000
# 5                 0         0
# 6                 0   7821000
# 7                 0   6399000
# 8                 0   9278000
# 9                 0   6037000
# 10                0  10837000
# 11                0  12333000
# 12                0   9123000
# 13                0   5894000
# 14                0   9495000
# 15                0   5626000
# 16                0   8772000
# 17                0  10217000
# 18                0   5624000
# 19                0   7214000
#
#                                             price_czk  \
# 0   {'value_raw': 13923000, 'unit': '', 'name': 'C...
# 1   {'value_raw': 8143000, 'unit': '', 'name': 'Ce...
# 2   {'value_raw': 7711000, 'unit': '', 'name': 'Ce...
# 3   {'value_raw': 7976000, 'unit': '', 'name': 'Ce...
# 4   {'value_raw': 10061000, 'unit': '', 'name': 'C...
# 5   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 6   {'value_raw': 7821000, 'unit': '', 'name': 'Ce...
# 7   {'value_raw': 6399000, 'unit': '', 'name': 'Ce...
# 8   {'value_raw': 9278000, 'unit': '', 'name': 'Ce...
# 9   {'value_raw': 6037000, 'unit': '', 'name': 'Ce...
# 10  {'value_raw': 10837000, 'unit': '', 'name': 'C...
# 11  {'value_raw': 12333000, 'unit': '', 'name': 'C...
# 12  {'value_raw': 9123000, 'unit': '', 'name': 'Ce...
# 13  {'value_raw': 5894000, 'unit': '', 'name': 'Ce...
# 14  {'value_raw': 9495000, 'unit': '', 'name': 'Ce...
# 15  {'value_raw': 5626000, 'unit': '', 'name': 'Ce...
# 16  {'value_raw': 8772000, 'unit': '', 'name': 'Ce...
# 17  {'value_raw': 10217000, 'unit': '', 'name': 'C...
# 18  {'value_raw': 5624000, 'unit': '', 'name': 'Ce...
# 19  {'value_raw': 7214000, 'unit': '', 'name': 'Ce...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 5   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 6   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 7   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 8   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 9   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 10  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 11  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 12  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 13  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 14  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 15  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 16  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 17  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 18  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 19  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                        name  region_tip  \
# 0    Prodej bytu 3+1 107 m²           0
# 1     Prodej bytu 3+1 74 m²           0
# 2     Prodej bytu 3+1 84 m²           0
# 3     Prodej bytu 3+1 92 m²           0
# 4    Prodej bytu 2+kk 82 m²           0
# 5   Prodej bytu 5+kk 273 m²           0
# 6    Prodej bytu 2+kk 44 m²           0
# 7     Prodej bytu 1+1 52 m²           0
# 8     Prodej bytu 3+1 98 m²           0
# 9     Prodej bytu 2+1 59 m²           0
# 10   Prodej bytu 2+kk 58 m²           0
# 11   Prodej bytu 3+kk 74 m²           0
# 12   Prodej bytu 2+kk 41 m²           0
# 13   Prodej bytu 2+kk 45 m²           0
# 14   Prodej bytu 2+kk 83 m²           0
# 15   Prodej bytu 2+kk 44 m²           0
# 16    Prodej bytu 4+1 88 m²           0
# 17   Prodej bytu 3+kk 75 m²           0
# 18   Prodej bytu 3+kk 68 m²           0
# 19    Prodej bytu 3+1 73 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.06413795169742, 'lon': 14.456196048...               False
# 1   {'lat': 50.07386895169742, 'lon': 14.524203048...               False
# 2   {'lat': 50.04609495169742, 'lon': 14.549500048...               False
# 3   {'lat': 50.04609495169742, 'lon': 14.549500048...               False
# 4   {'lat': 50.05469295169742, 'lon': 14.420048048...               False
# 5   {'lat': 50.07937395169742, 'lon': 14.429558048...               False
# 6   {'lat': 50.03603895169742, 'lon': 14.320877048...               False
# 7   {'lat': 50.05442595169742, 'lon': 14.454590048...               False
# 8   {'lat': 50.100335951697424, 'lon': 14.52812704...                True
# 9   {'lat': 50.10500095169742, 'lon': 14.481135048...               False
# 10  {'lat': 50.06971895169742, 'lon': 14.362342048...               False
# 11  {'lat': 50.060856951697424, 'lon': 14.45113604...               False
# 12  {'lat': 50.03918195169742, 'lon': 14.458092048...               False
# 13  {'lat': 50.03918195169742, 'lon': 14.458092048...               False
# 14  {'lat': 50.05245395169742, 'lon': 14.378506048...               False
# 15  {'lat': 49.99656795169742, 'lon': 14.440068048...               False
# 16  {'lat': 49.99796795169742, 'lon': 14.441342048...               False
# 17  {'lat': 50.07276695169742, 'lon': 14.464741048...               False
# 18  {'lat': 50.01484495169742, 'lon': 14.535800048...               False
# 19  {'lat': 50.02752495169742, 'lon': 14.353138048...               False
#
# [20 rows x 27 columns]

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
def convert_sreality_data_to_df(sreality_data):
    return pd.DataFrame(sreality_data["_embedded"][""])

raw = convert_sreality_data_to_df(d)

# %%
raw.head()

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
df = request_sreality(0, 'flat', 'sell', 10)
df.head()

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
raw.shape
# Out:
# (21, 27)

# %%
request_sreality
# Out:
# <function __main__.request_sreality(page, category_main_str, category_type_str, locality_region_id=10)>

# %%
def request_multiply_sreality(start_page, end_page, category_main_str, category_type_str, locality_region_id=10):
    
    return pd.concat(list_of_dfs)

df = request_multiply_sreality(1, 5, 'flat', 'sell',10)
df.shape
# Out:
# (103, 27)

# %% [markdown]
# ## Task 2: Cleaning data
#
# ### 2a. Filter columns
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %% [markdown]
# ### 2b. Get flat type from name
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * try picking third word in string
# * check meaningfulness using `.value_counts()`

# %% [markdown]
# ### 2c. Get area from name
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * if this also fail, then you will need to use regex

# %%
def name_to_area(nm):

    return 

clean['area_2'] = clean.name.apply(name_to_area)
clean

# %% [markdown]
# ## Bonus: Convert `labelsAll` into categorical variables
#
# ### Task 4a. Get all possible label names
# * deal with nested-list structure
# * Hint: try to sum the whole column
# * Needed to Iterate through all labels in all rows and

# %% [markdown]
# ### 4b. Test existence of label `cellar` for offers
# * again deal with nested list of list structure
# * write generic function `test_existence_of_label(offer_labels,label)`

# %% [markdown]
# ### 4c. Test existence of all possible labels
# * use apply returning series with all labels
